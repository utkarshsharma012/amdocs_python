# %%
#Read CSV File 
import pandas as pd
df=pd.read_csv('nyc_weather.csv')
# df.info()

# %% [markdown]
# # Select The Rows

# %%
df.head()# Top 5 Rows
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea_Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.head(3)# return Top 3 Rows
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea_Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
df.tail() # last 5 rows
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea_Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df.tail(6)# last 6 rows
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea_Level PressureIn  \
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 25               10           7.0               0           2    NaN
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# ...

# %%
df.sample()# 1 random row
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea_Level PressureIn  \
# 20  1/21/2016           31        11        45                 30.15
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 20               10           6.0               0           1    NaN
#
#     WindDirDegrees
# 20             312

# %%
df.sample(3)# 3 random rows
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea_Level PressureIn  \
# 6    1/7/2016           39        11        33                 30.28
# 24  1/25/2016           34        18        54                 30.25
# 3    1/4/2016           25         9        44                 30.05
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 6                10           2.0               0           3    NaN
# 24               10           3.0               0           2    NaN
# 3                10           9.0               0           3    NaN
#
#     WindDirDegrees
# 6              293
# 24             286
# 3              345

# %% [markdown]
# # slicing
# # df[-1:-(len(df)+1):-5]
#
# df[-1:-32:-5]> -1,-6,-11 ....

# %%
df.shape
# Out:
# (31, 11)

# %%
df.size
# Out:
# 341

# %%
len(df)# total no of Rows
# Out:
# 31

# %%
#index of columns
df.columns

h=list(df.columns)
h
# Out:
# ['EST',
#  'Temperature',
#  'DewPoint',
#  'Humidity',
#  'Sea_Level PressureIn',
#  'VisibilityMiles',
#  'WindSpeedMPH',
#  'PrecipitationIn',
#  'CloudCover',
#  'Events',
#  'WindDirDegrees']

# %%
#index of rows
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df[-1:-(len(df)+1):-5]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea_Level PressureIn  \
# 30  1/31/2016           46        28        52                 29.90
# 25  1/26/2016           43        29        56                 30.03
# 20  1/21/2016           31        11        45                 30.15
# 15  1/16/2016           47        37        70                 29.52
# 10  1/11/2016           33         8        37                 29.92
# 5    1/6/2016           33         4        35                 30.50
# 0    1/1/2016           38        23        52                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 30               10           5.0               0           0    NaN
# 25               10           7.0               0           2    NaN
# 20               10           6.0               0           1    NaN
# 15                8           7.0            0.24           7   Rain
# ...

# %% [markdown]
# # Q:- select and Return the Odd No of Rows ?

# %%
new_df=df[0:len(df):2]
new_df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea_Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 2    1/3/2016           40        21        47                 29.86
# 4    1/5/2016           20        -3        41                 30.57
# 6    1/7/2016           39        11        33                 30.28
# 8    1/9/2016           44        38        77                 30.16
# 10  1/11/2016           33         8        37                 29.92
# 12  1/13/2016           26         4        42                 29.94
# 14  1/15/2016           43        31        62                 29.82
# 16  1/17/2016           36        23        66                 29.78
# 18  1/19/2016           22         3        42                 30.03
# 20  1/21/2016           31        11        45                 30.15
# 22  1/23/2016           26        21        78                 29.77
# 24  1/25/2016           34        18        54                 30.25
# ...

# %% [markdown]
# # Select the columns ?

# %%
# a=df.EST # m*1
a=df['Sea_Level PressureIn'] #m*1
print(type(a))#Series
a.head(3)
# Out:
# <class 'pandas.core.series.Series'>
# 0    30.03
# 1    30.02
# 2    29.86
# Name: Sea_Level PressureIn, dtype: float64

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea_Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %% [markdown]
# #Multiple column select ?

# %%
a=df[['VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn']] # new_df=df_obj[[list of columnnamses]]
print(type(a))#DataFrame > m*n > 31*3
print(a.shape)
a.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (31, 3)
#    VisibilityMiles  WindSpeedMPH PrecipitationIn
# 0               10           8.0               0
# 1               10           7.0               0
# 2               10           8.0               0
# 3               10           9.0               0
# 4               10           5.0               0

# %% [markdown]
# # Q2: Select the top 10 Even no of rows with any 6 columns ?

# %%
new_df=df[1:len(df):2][['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea_Level PressureIn','VisibilityMiles']].head(10)
print(new_df.info())
new_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 1 to 19
# Data columns (total 6 columns):
# EST                     10 non-null object
# Temperature             10 non-null int64
# DewPoint                10 non-null int64
# Humidity                10 non-null int64
# Sea_Level PressureIn    10 non-null float64
# VisibilityMiles         10 non-null int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 564.0+ bytes
# None
#           EST  Temperature  DewPoint  Humidity  Sea_Level PressureIn  \
# 1    1/2/2016           36        18        46                 30.02
# 3    1/4/2016           25         9        44                 30.05
# 5    1/6/2016           33         4        35                 30.50
# 7    1/8/2016           39        29        64                 30.20
# 9   1/10/2016           50        46        71                 29.59
# 11  1/12/2016           35        15        53                 29.85
# ...

# %% [markdown]
# # When did it Rain ?

# %%
new_df=df[df['Events']=="Rain"][['EST','DewPoint','Events']]
new_df
# Out:
#           EST  DewPoint Events
# 8    1/9/2016        38   Rain
# 9   1/10/2016        46   Rain
# 15  1/16/2016        37   Rain
# 26  1/27/2016        22   Rain

# %% [markdown]
# Return Rows Exclude the Rain ?

# %%
new_df=df[df['Events']!="Rain"][['EST','DewPoint','Events']].head(3)
new_df
# Out:
#         EST  DewPoint Events
# 0  1/1/2016        23    NaN
# 1  1/2/2016        18    NaN
# 2  1/3/2016        21    NaN

# %% [markdown]
# # Q-2 When Rain and Snow Both Happend ?
#
# & >and
#
# | > or
#
# ~ > not

# %%
new_df=df[(df['Events']=="Rain")  |  (df['Events']=="Snow")][['EST','Events','Temperature']]
new_df
# Out:
#           EST Events  Temperature
# 8    1/9/2016   Rain           44
# 9   1/10/2016   Rain           50
# 15  1/16/2016   Rain           47
# 17  1/18/2016   Snow           25
# 21  1/22/2016   Snow           26
# 23  1/24/2016   Snow           28
# 26  1/27/2016   Rain           41

# %% [markdown]
# # Q-3 # Return The Rows when Temperature<=34 and windspeed <= avg value of windspeed ?

# %%
new_df=df[(df['Temperature']<=34)  & (df['WindSpeedMPH']<=df['WindSpeedMPH'].mean())][['EST','Events','Temperature','WindSpeedMPH']]
new_df
# Out:
#           EST Events  Temperature  WindSpeedMPH
# 4    1/5/2016    NaN           20           5.0
# 5    1/6/2016    NaN           33           4.0
# 13  1/14/2016    NaN           30           5.0
# 19  1/20/2016    NaN           32           6.0
# 20  1/21/2016    NaN           31           6.0
# 23  1/24/2016   Snow           28           6.0
# 24  1/25/2016    NaN           34           3.0

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
df['WindSpeedMPH'].max()
# Out:
# 16.0

# %%
df['WindSpeedMPH'].min()
# Out:
# 2.0

# %%
df['WindSpeedMPH'].size
# Out:
# 31

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df.loc[[0,6],['EST','Events']] # value of row index and column index# df.loc[row_value,column_value]
# Out:
#         EST Events
# 0  1/1/2016    NaN
# 6  1/7/2016    NaN

# %%
df.iloc[0:7,0:3] # iloc > index numbers of row and columns
# Out:
#         EST  Temperature  DewPoint
# 0  1/1/2016           38        23
# 1  1/2/2016           36        18
# 2  1/3/2016           40        21
# 3  1/4/2016           25         9
# 4  1/5/2016           20        -3
# 5  1/6/2016           33         4
# 6  1/7/2016           39        11

# %% [markdown]
# # When did it Rain ?

# %% [markdown]
# set_index

# %%
df.set_index('Events',inplace=True)
df.index
# Out:
# Index([       nan,        nan,        nan,        nan,        nan,        nan,
#               nan,        nan,     'Rain',     'Rain',        nan,        nan,
#               nan,        nan,        nan,     'Rain', 'Fog-Snow',     'Snow',
#               nan,        nan,        nan,     'Snow', 'Fog-Snow',     'Snow',
#               nan,        nan,     'Rain',        nan,        nan,        nan,
#               nan],
#       dtype='object', name='Events')

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea_Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'WindDirDegrees'],
#       dtype='object')

# %%
df.loc['Rain',['EST','Temperature','WindSpeedMPH']]
# Out:
#               EST  Temperature  WindSpeedMPH
# Events
# Rain     1/9/2016           44           8.0
# Rain    1/10/2016           50           NaN
# Rain    1/16/2016           47           7.0
# Rain    1/27/2016           41           7.0

# %%
df.loc[['Rain','Snow'],['EST','Temperature','WindSpeedMPH']]
# Out:
#               EST  Temperature  WindSpeedMPH
# Events
# Rain     1/9/2016           44           8.0
# Rain    1/10/2016           50           NaN
# Rain    1/16/2016           47           7.0
# Rain    1/27/2016           41           7.0
# Snow    1/18/2016           25          12.0
# Snow    1/22/2016           26           NaN
# Snow    1/24/2016           28           6.0

# %%
df.reset_index(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
# Events                  9 non-null object
# EST                     31 non-null object
# Temperature             31 non-null int64
# DewPoint                31 non-null int64
# Humidity                31 non-null int64
# Sea_Level PressureIn    31 non-null float64
# VisibilityMiles         31 non-null int64
# WindSpeedMPH            28 non-null float64
# PrecipitationIn         31 non-null object
# CloudCover              31 non-null int64
# WindDirDegrees          31 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.7+ KB
